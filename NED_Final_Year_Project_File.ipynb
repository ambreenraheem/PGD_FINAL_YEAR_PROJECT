# %% [markdown]
# <a href="https://colab.research.google.com/github/ambreenraheem/PGD_FINAL_YEAR_PROJECT/blob/main/NED_Final_Year_Project_File.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # (NED) POST GRADUATE DIPLOMA FINAL YEAR PROJECT
#
# # BY AMBREEN ABDUL RAHEEM
# # SUPERVISED BY SIR IMRAN BASHIR
# ## Pakistan NGO Fraud Detection Dataset
# Date: 20-November-2025
# ###📘 Overview
# This dataset represents financial and operational data collected from multiple Non-Governmental Organizations (NGOs) operating across Pakistan.
# The primary objective of this dataset is to analyze and detect fraudulent activities in NGO project funding and expense reporting.
#
# The data includes information about project proposals, financial requests, bank details, vendors, population demographics, and audit indicators.
# It can be used to identify suspicious trends, detect anomalies, and build machine learning models for fraud detection in the non-profit sector.
#
# 🧩 Dataset Structure
#
# Column Name	Description
#
# - Date:	Date when the project application or transaction was recorded.
# - Applicant_Name:	Name of the person or representative submitting the application.
# - NGO_Name:	Registered name of the NGO involved in the project.
# - City_Town_Village:	Geographical area where the NGO operates or the project takes place.
# - Project_Name:	Title or description of the project submitted for funding.
# - Requested_Amount_PKR:	The amount requested by the NGO for the project (in PKR).
# - Legitimate_Estimate_PKR:	The legitimate or auditor-approved estimate of required funding.
# - Fraud_Type:	Indicates whether the project is approved or fraudulent and what kind of fraud occurred.
# - Fraud_Indicator:	Qualitative description of audit findings or irregularities.
# - Population_Census_Record: Official population data of the area (for demographic comparison).
# - Invoice_ID:	Unique identifier for the submitted invoice.
# - Vendor_Name:	The vendor or supplier linked with project purchases or reimbursements.
# - Bank_Reference_No:	Transaction or reference number associated with NGO's funding transfer.
# - Bank_Name:	Bank used by the NGO for fund transfer.
# - Is_Fraud:	Boolean field (True/False) indicating if the case was identified as fraud.
#
#
# 🎯 Purpose of Analysis
#
# This dataset is designed to help data analysts, auditors, and government agencies identify fraud patterns and high-risk NGOs or vendors.
# The key goals include:
#
# 1- Detecting financial anomalies such as exaggerated funding requests.
#
# 2- Understanding geographic and institutional risk factors contributing to fraud.
#
# 3- Monitoring bank and vendor activities for repeated fraudulent behavior.
#
# 4- Training predictive machine learning models for early fraud detection.
#
# 5- Enhancing transparency and accountability in Pakistan’s non-profit and development sector.
#
# 💡 Potential Use Cases
#
# - Fraud Detection Systems: Build models that predict if a project proposal is likely to be fraudulent.
# - Audit Dashboards: Visualize NGO activities, high-risk zones, and suspicious transactions.
# - Policy Design: Help government agencies strengthen NGO regulations and funding procedures.
# - Vendor Screening: Detect vendors repeatedly involved in fraudulent projects.
# - Educational Projects: Ideal dataset for learning data cleaning, EDA, and fraud detection with Python or Power BI.
#
# ⚠️ Disclaimer
# This dataset is synthetic but realistic, created for educational and analytical purposes.
# It does not represent any real NGO or individual but mimics actual data patterns observed in NGO funding and fraud audits.

# %% [markdown]
# ### 01-Step: Importing Libraries and loadig Dataset of the Project

# %%
# Full Cleaned Fraud Detection Project with NGO Data

import pandas as pd
import numpy as np
import seaborn as sns
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models

# %%
df1 = pd.read_excel('/content/pakistan_ngo_fraud_perfect_01_projectdataset.xlsx')

# %%
df1
# Out:
#           Date  Applicant_Name                       NGO_Name  \
# 0   2024-03-19   Khadija Anwar  Sahara Development Foundation
# 1   2021-01-15  Hassan Qureshi  Sahara Development Foundation
# 2   2022-06-13   Khadija Ahmed        Green Villages Pakistan
# 3   2024-06-28       Hira Shah           Roshan Welfare Trust
# 4   2021-12-13        Ali Butt        Green Villages Pakistan
# ..         ...             ...                            ...
# 994 2022-04-28          Nadeem           Roshan Welfare Trust
# 995 2023-06-16         Mansoor  Sahara Development Foundation
# 996 2022-09-29          Zaffar        Green Villages Pakistan
# 997 2024-10-02   Saleem Jawaid        Green Villages Pakistan
# 998 2023-01-23        Deen Bux        Green Villages Pakistan
#
#     City_Town_Village                           Project_Name  \
# 0              Multan     Maternal and Child Health Outreach
# 1              Lahore            Rural School Rehabilitation
# 2              Quetta     Maternal and Child Health Outreach
# 3              Sukkur                 Community Health Camps
# 4          Rawalpindi     Maternal and Child Health Outreach
# ..                ...                                    ...
# 994           Sialkot         Disaster Relief Rapid Response
# 995        Rawalpindi                 Community Health Camps
# 996           Karachi  Tree-Plantation & Greenery Initiative
# 997           Sialkot  Tree-Plantation & Greenery Initiative
# 998          Peshawar                 Community Health Camps
#
#     Requested_Amount_PKR Legitimate_Estimate_PKR                   Fraud_Type  \
# 0           Rs 1,216,200            Rs 1,216,200                     Approved
# 1             Rs 546,400              Rs 489,824  Expense/Reimbursement Fraud
# 2           Rs 1,194,400            Rs 1,194,450                     Approved
# 3             Rs 423,800              Rs 423,800                     Approved
# 4          Rs 11,743,200           Rs 11,743,200                     Approved
# ..                   ...                     ...                          ...
# 994        Rs 32,506,580           Rs 32,506,580                     Approved
# 995        Rs 16,349,985           Rs 16,349,985                     Approved
# 996         Rs 9,912,257            Rs 9,912,257                     Approved
# 997         Rs 2,753,000            Rs 2,753,000                     Approved
# 998        Rs 16,335,566           Rs 16,335,566                     Approved
#
#                           Fraud_Indicator  Population_Census_Record  \
# 0               Compliant with Guidelines                   2215381
# 1    Invoices lack vendor contact details                  13004135
# 2               Compliant with Guidelines                   1565546
# 3               Compliant with Guidelines                   1625467
# 4               Compliant with Guidelines                   3357612
# ..                                    ...                       ...
# 994             Compliant with Guidelines                    835337
# 995             Compliant with Guidelines                   3357612
# 996             Compliant with Guidelines                  18870000
# 997             Compliant with Guidelines                    835337
# 998             Compliant with Guidelines                   1905975
#
#          Invoice_ID                      Vendor_Name  Bank_Reference_No  \
# 0      INV-NF57VH2D           GreenLeaf Construction  BR-SCB-4302499307
# 1      INV-YAECEEUT    Ahmed Builders & Construction  BR-ABL-4314102640
# 2      INV-GYMRRQSR            OneMetal Construction  BR-ASK-7109989950
# 3      INV-XI5P2QFS           Metro Office Solutions  BR-NBP-0400160385
# 4      INV-A42W44WU           PakTech Equipments Ltd  BR-UBL-9375262635
# ..              ...                              ...                ...
# 994   INV-S07JOFTGY  United Medical & Relief Vendors   BR-HBL-853729833
# 995  INV-372V45RTYV            All-Pakistan Medicals   BR-HBL-529523696
# 996  INV-T862V3TREW               Shoab-Bhai Nursery  BR-MCB-9087580586
# 997  INV-D5S0SOTVHG          Ali Plantation & Decore  BR-MEBL-907853365
# 998   INV-TL1D0UHGY              EduServe Publishers   BR-MCB-162620999
#
#                        Bank_Name  Is_Fraud
# 0    Standard Chartered Pakistan     False
# 1                    Allied Bank      True
# 2                    Askari Bank     False
# 3      National Bank of Pakistan     False
# 4            United Bank Limited     False
# ..                           ...       ...
# 994           Habib Bank Limited     False
# 995           Habib Bank Limited     False
# 996             MCB Bank Limited     False
# 997                  Meezan Bank     False
# 998             MCB Bank Limited     False
#
# [999 rows x 15 columns]

# %% [markdown]
# ### 02-Step: Data Visualization

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Is_Fraud'].value_counts()
    for x_label, grp in df1.groupby('Fraud_Type')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Fraud_Type')
_ = plt.ylabel('Is_Fraud')
plt.title('Fraud_Type vs Is_Fraud')
# Out:
# Text(0.5, 1.0, 'Fraud_Type vs Is_Fraud')

# %%
fraud_type_by_ngo = pd.crosstab(df1['NGO_Name'], df1['Fraud_Type'])

plt.figure(figsize=(14, 8))
fraud_type_by_ngo.plot(kind='bar', stacked=True, colormap='viridis', figsize=(14, 8))
plt.title('Distribution of NGO Names by Fraud Type', fontsize=16, fontweight='bold')
plt.xlabel('NGO Name', fontsize=12)
plt.ylabel('Number of Projects', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Fraud Type', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
ngo_counts = df1['NGO_Name'].value_counts()

plt.figure(figsize=(12, 7))
sns.barplot(x=ngo_counts.index, y=ngo_counts.values, palette='viridis')
plt.title('Distribution of Projects by NGO Name', fontsize=14, fontweight='bold')
plt.xlabel('NGO Name', fontsize=12)
plt.ylabel('Number of Projects', fontsize=12)
plt.xticks(rotation=45, ha='right') # Rotate labels for better readability
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3018536215.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=ngo_counts.index, y=ngo_counts.values, palette='viridis')

# %%
city_project_counts = df1['City_Town_Village'].value_counts()

plt.figure(figsize=(16, 8))
sns.barplot(x=city_project_counts.index, y=city_project_counts.values, palette='viridis')
plt.title('Distribution of Projects by City/Town/Village', fontsize=16, fontweight='bold')
plt.xlabel('City/Town/Village', fontsize=12)
plt.ylabel('Number of Projects', fontsize=12)
plt.xticks(rotation=90, ha='center') # Rotate labels for better readability
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-1613907119.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=city_project_counts.index, y=city_project_counts.values, palette='viridis')

# %% [markdown]
# ### Preprocessing of Dataset

# %%
# Reset pandas option to default display rows first
pd.reset_option('display.max_rows')

# Set pandas option to display all rows
pd.set_option('display.max_rows', None)

# %%
# Set pandas option to display all rows
pd.set_option('display.max_rows', None)

df1['City_Town_Village'].value_counts()
# Out:
# City_Town_Village
# Sialkot                   95
# Karachi                   94
# Multan                    93
# Peshawar                  84
# Quetta                    81
# Abbottabad                80
# Faisalabad                77
# Rawalpindi                77
# Sukkur                    60
# Lahore                    58
# Turbat                    13
# Hyderabad                  7
# Bahawalpur                 7
# Swabi                      7
# Haripur                    7
# Dera Ismail Khan           6
# Mingora                    6
# Dera Bugti                 6
# Larkana                    5
# Zhob                       5
# Sargodha                   5
# Nowshera                   5
# Sajawal                    5
# Gwadar                     5
# Kohat                      5
# Ormara                     5
# Loralai Town               5
# Gujrat                     4
# Chagai                     4
# Mansehra                   4
# Kamber Shahdadkot          4
# Sibi                       4
# Jacobabad                  4
# Gujranwala                 4
# Sahiwal                    4
# Mirpur Khas                3
# Moro City                  3
# Ghotki                     3
# Thatta                     3
# Ranikhait Village          3
# Bannu                      3
# Muzafarabad                3
# Kila Abdullah District     2
# Khairpur                   2
# Lasbela                    2
# Killa Saifullah            2
# Attock                     2
# Mardan                     2
# Seeta Village              2
# Khuzdar                    2
# Sahiwall                   2
# Dera Ghazi Khan            2
# Pasni                      2
# Dadu City                  2
# Umerkot                    2
# Badin                      1
# Kalat                      1
# Khair Pur                  1
# Chukwal                    1
# Shahdad Pur                1
# Rani Ghoath                1
# Jafarabad                  1
# Karachi, Korangi           1
# Jhal Magsi                 1
# Chaman                     1
# Karachi,bhans Coloney      1
# Gharo                      1
# Awaran                     1
# Sanghar                    1
# Hub                        1
# Shikarpur                  1
# JAN Muhannad Ghot          1
# Name: count, dtype: int64

# %%
df1['Project_Name'].value_counts()
# Out:
# Project_Name
# Clean Water & Sanitation Project                    127
# Maternal and Child Health Outreach                   91
# Tree-Plantation & Greenery Initiative                90
# Community Health Camps                               83
# Rural School Rehabilitation                          76
# Vocational Training for Youth                        72
# Covid-19 Awareness & Vaccination Support             70
# Disaster Relief Rapid Response                       68
# Girls EDUCATION Drive                                62
# Livelihoods: Small Business Grants                   54
# Community Health Camps in small Towns                 8
# Solar Panel Systems in Rural Areas                    7
# Maternal and Child Health Centers                     6
# IT Training Center for Youth in Rural Area            5
# Polio Awareness & Vaccination Support                 5
# Rural Govt. School Rehabilitation                     4
# Vocational Training for Youth in Rural Area           4
# Govt. School Rehabilitation                           4
# Girls & Boys EDUCATION Plan                           4
# Community Health Centers Building                     4
# Children Vaccinations in Rural Areas                  4
# Small Aggriculture Businesses                         4
# Disaster Relief Rapid Response for Roral Area         4
# Computer Training Centers for Youth                   4
# Girls EDUCATION Centers                               4
# Disaster Relief Rapid Response in Medical camp        3
# Small Businesses And Development for Women            3
# Livelihoods: Small Business Grants in Dairy           3
# Dengue Awareness Program                              3
# Community Education School for Women                  3
# Boys High School Reconstraction                       3
# Community Health Awareness Camp                       2
# Rural Boys High School Rehabilitation                 2
# Disaster Relief Rapid Response in School              2
# Aggriculture and Farming Growth in Rural Area         2
# Govt. High School Rehabilitation                      2
# Rural Boys College School Rehabilitation              2
# Rural Govt. Girls School Rehabilitation               2
# Rural Govt.School Rehabilitation in Nazim Abad        2
# Rural School Free Books Distributions                 2
# Community Health Camps for Children                   2
# Community Health Camps for women                      2
# Disaster Relief Rapid Response                        2
# Small Garments Business for Housewise                 2
# Rural Covt. School Rehabilitation                     2
# Buildiing Small Books Install                         2
# Vocational Art&Craft Training Centers for Girls       2
# Training of Nursing Course for Youth                  2
# Small Business of Fishery                             2
# Rural School Rehabilitation                           2
# Vocational IT-Training for Youth                      2
# Disaster Relief Rapid Response for House              2
# Rural High School Rehabilitation                      2
# Rural College Rehabilitation for Boys                 2
# Small Business Grants                                 2
# Art and Craft with Young Girl                         2
# Maternal and Child Health Vaccination                 2
# Small Businesses for Women                            2
# Govt.High School and College Reconstruction           2
# Vocational Training for Youth  in Liyari              2
# Girls IT-EDUCATION Drive                              1
# Girls Basic EDUCATION Drive                           1
# Rural Boys Primary School Rehabilitation              1
# Small Business Grants for Youth                       1
# Boys-EDUCATION Plan                                   1
# Small Medical Camps                                   1
# Rural Girls Middle School Rehabilitation              1
# Vocational Training Centers for Youth                 1
# Town High School Rehabilitation                       1
# Rural  Primary School Rehabilitation                  1
# Girls Primary EDUCATION Drive                         1
# Rural Students Rehabilitation                         1
# Schools And Colleges Rehabilitation                   1
# Girls EDUCATION & VOCATIONAL Training                 1
# School And Colleges Rehabilitation                    1
# Women Health Outreach & Camp                          1
# Polio & Dengue Awareness Campain                      1
# Child Health Outreach Camp                            1
# Child Health  Awareness & Outreach                    1
# Clean Water & Sanitation Project For Towns            1
# Maternal and Child Health Medical Camp                1
# Disaster Relief Rapid Response in Education           1
# Girls High EDUCATION Plan                             1
# Vocational Training for Women                         1
# Awareness & Vaccination Support                       1
# Dengue Awareness & Support Camp                       1
# Small Books Install                                   1
# Housing Society Development in Flooded Area           1
# Distribution of Animal Medicine                       1
# Dengue Awareness Camp                                 1
# Rebuild Child Health Centers                          1
# Govt. School & College Rehabilitation                 1
# Clean Water & Cannal for Rural Area                   1
# Rural Govt. Medical Centers Rehabilitation            1
# Rural School Rehabilitation & Reconstructions         1
# Dairy Farm Houses For small Businesses                1
# Building Community Health Center for Child            1
# Building Community Health Center                      1
# Child Health Care Outreach Camp                       1
# Flood Relief Camps                                    1
# Rural School & Colleges Rehabilitation                1
# Small Villages for Fishermen                          1
# Rebuild Vaccination Support Centers                   1
# Earlly ChildHood Education Program                    1
# Girls Health Drive Long Term Program                  1
# Health Training for Youth Girls                       1
# Polio Vaccination Awareness Program                   1
# Disaster Relief Rapid Response of Children            1
# Disaster Relief Rapid Response in Rehabilitation      1
# Disaster Relief Rapid Response in Basic Needs         1
# Small Handmade Craft Businesses                       1
# Computer Centers for Girls                            1
# Vocational Training for Youth in Computers            1
# Girls Earlly Age Health Awareness                     1
# Boys School Rehabilitation in Rural Area              1
# Got. Girls College EDUCATION Program                  1
# Children High Education Program                       1
# Govt. Girls EDUCATION Program                         1
# Disaster Relief Rapid Response in Aggriculture        1
# Name: count, dtype: int64

# %%
df1['NGO_Name'].value_counts()
# Out:
# NGO_Name
# Sahara Development Foundation     217
# Sehat & Taleem Initiative         204
# Roshan Welfare Trust              197
# Green Villages Pakistan           162
# Naya Umeed NGO                    155
# Nishat Welfare Organization        29
# Green Pakistan Welfare             17
# TALEEM-DO Welfare Organization      6
# KARWAN HAMARA NGO                   5
# Hayaat Education Trust              3
# Pak-Sahar Trust                     2
# KHIDMAT Welfare Organization        1
# Mustukbil HAMARA Trust              1
# Name: count, dtype: int64

# %%
df1['Is_Fraud'].value_counts()
# Out:
# Is_Fraud
# False    970
# True      29
# Name: count, dtype: int64

# %%
df1['Bank_Name'].value_counts()
# Out:
# Bank_Name
# Habib Bank Limited             132
# National Bank of Pakistan      107
# Askari Bank                    104
# Standard Chartered Pakistan    103
# Allied Bank                     99
# United Bank Limited             99
# Faysal Bank                     98
# Meezan Bank                     96
# Bank Alfalah                    92
# MCB Bank Limited                69
# Name: count, dtype: int64

# %%
df1['Fraud_Indicator'].value_counts()
# Out:
# Fraud_Indicator
# Compliant with Guidelines                        970
# Invoices lack vendor contact details              11
# Vendor is related party                            6
# Beneficiary counts inconsistent                    3
# Ghost vendor detected                              3
# Mismatch between receipts and bank statements      2
# Project timeline unrealistic                       2
# Applicant credentials unverifiable                 1
# Multiple claims for same expense                   1
# Name: count, dtype: int64

# %%
df1['Fraud_Type'].value_counts()
# Out:
# Fraud_Type
# Approved                       970
# Procurement & Vendor Fraud      12
# Expense/Reimbursement Fraud     11
# Grant Application Fraud          6
# Name: count, dtype: int64

# %% [markdown]
# ### 03-Step: Feature Engineering to find out the insight of the Dataset

# %%
# -------- Feature Engineering --------

# 1 Clean numeric fields
def clean_amount(x):
    if isinstance(x, str):
        return float(x.replace("Rs", "").replace(",", "").replace(" ", "").strip())
    return x

df1["Requested_Amount_PKR"] = df1["Requested_Amount_PKR"].apply(clean_amount)
df1["Legitimate_Estimate_PKR"] = df1["Legitimate_Estimate_PKR"].apply(clean_amount)
df1["Population_Census_Record"] = df1["Population_Census_Record"].replace(",", "", regex=True).astype(float)

# 2 Fund Gap (requested vs legitimate)
df1["Fund_Gap_PKR"] = df1["Requested_Amount_PKR"] - df1["Legitimate_Estimate_PKR"]

# 3 Population Influence — funding per capita
df1["Funding_per_Capita"] = df1["Requested_Amount_PKR"] / df1["Population_Census_Record"]
df1["Funding_per_Capita"].fillna(0, inplace=True)

# 4 Bank Frequency — how many projects per bank
bank_counts = df1["Bank_Name"].value_counts().to_dict()
df1["Bank_Frequency"] = df1["Bank_Name"].map(bank_counts)


# 5 Fraud Label Encoding (convert True/False → 1/0)
df1["Is_Fraud"] = df1["Is_Fraud"].astype(int)

# 🎯 Final engineered dataset
engineered_features = [
    "Requested_Amount_PKR", "Legitimate_Estimate_PKR", "Fund_Gap_PKR",
    "Funding_per_Capita", "Is_Fraud", "Bank_Frequency"
]

df_final = df1[engineered_features]
df_final.head(10)
# Out:
# /tmp/ipython-input-750893634.py:18: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Funding_per_Capita"].fillna(0, inplace=True)
#    Requested_Amount_PKR  Legitimate_Estimate_PKR  Fund_Gap_PKR  \
# 0             1216200.0                1216200.0           0.0
# 1              546400.0                 489824.0       56576.0
# 2             1194400.0                1194450.0         -50.0
# 3              423800.0                 423800.0           0.0
# 4            11743200.0               11743200.0           0.0
# 5              104000.0                 104000.0           0.0
# 6              128000.0                 128000.0           0.0
# 7               89600.0                  89300.0         300.0
# 8             1191700.0                1191650.0          50.0
# 9             1750700.0                1750700.0           0.0
#
#    Funding_per_Capita  Is_Fraud  Bank_Frequency
# 0            0.548980         0             103
# 1            0.042017         1              99
# 2            0.762929         0             104
# 3            0.260725         0             107
# 4            3.497486         0              99
# 5            0.005511         0             107
# 6            0.067157         0              98
# 7            0.047010         0             132
# 8            0.761204         0             107
# 9            0.134626         0              99

# %%
df_final.plot(kind='scatter', x='Requested_Amount_PKR', y='Legitimate_Estimate_PKR', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)
plt.xlabel('Requested_Amount_PKR')
_ = plt.ylabel('Legitimate_Estimate_PKR')
_ = plt.title('Requested_Amount_PKR vs Legitimate_Estimate_PKR')

# %% [markdown]
# ### 04-Step: Scaling

# %%
# ------------------- Step 4: Scaling ----------------------

# Separate features (X) and target (y)
X = df_final.drop('Is_Fraud', axis=1)
y = df_final['Is_Fraud']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# ### 05-Step: Autoencoder Model for training

# %%
# ------------------- Step 5: Autoencoder Model ----------------------

# Separate normal (non-fraud) data for training
X_normal = X_scaled[y == 0]
X_fraud = X_scaled[y == 1]

input_dim = X_scaled.shape[1]

# Autoencoder Architecture
autoencoder = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(input_dim,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(input_dim, activation='linear')  # Reconstruct input
])

autoencoder.compile(optimizer='adam', loss='mse')

# Train only on normal (non-fraud) data
history = autoencoder.fit(
    X_normal, X_normal,
    epochs=50,
    batch_size=256,
    validation_split=0.1,
    verbose=1
)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.7208 - val_loss: 0.8160
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.7646 - val_loss: 0.7266
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.6891 - val_loss: 0.6425
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.5505 - val_loss: 0.5614
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.4908 - val_loss: 0.4849
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.3984 - val_loss: 0.4083
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.4203 - val_loss: 0.3225
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2856 - val_loss: 0.2490
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.2343 - val_loss: 0.1865
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1955 - val_loss: 0.1326
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1972 - val_loss: 0.0896
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.1219 - val_loss: 0.0554
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1120 - val_loss: 0.0374
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.1073 - val_loss: 0.0300
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0704 - val_loss: 0.0278
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0876 - val_loss: 0.0267
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0347 - val_loss: 0.0254
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0245 - val_loss: 0.0227
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0531 - val_loss: 0.0203
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0454 - val_loss: 0.0178
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0228 - val_loss: 0.0160
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0306 - val_loss: 0.0145
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0086 - val_loss: 0.0134
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0216 - val_loss: 0.0125
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0163 - val_loss: 0.0118
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0119 - val_loss: 0.0112
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0048 - val_loss: 0.0112
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.0034 - val_loss: 0.0109
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0039 - val_loss: 0.0103
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0031 - val_loss: 0.0099
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0027 - val_loss: 0.0097
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - val_loss: 0.0095
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0018 - val_loss: 0.0090
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0016 - val_loss: 0.0085
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0015 - val_loss: 0.0082
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0014 - val_loss: 0.0078
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0015 - val_loss: 0.0075
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0013 - val_loss: 0.0072
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0012 - val_loss: 0.0068
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0011 - val_loss: 0.0067
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0012 - val_loss: 0.0064
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0010 - val_loss: 0.0060
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0058
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0010 - val_loss: 0.0058
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 9.5433e-04 - val_loss: 0.0056
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.9541e-04 - val_loss: 0.0053
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.2371e-04 - val_loss: 0.0053
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.0634e-04 - val_loss: 0.0052
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.0269e-04 - val_loss: 0.0050
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.6960e-04 - val_loss: 0.0049

# %%
# Reconstruction error for all data
X_pred = autoencoder.predict(X_scaled)
recon_error = np.mean(np.square(X_scaled - X_pred), axis=1)

# Save reconstruction errors
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)
X_scaled_df['Reconstruction_Error'] = recon_error


# Threshold for anomaly detection (fraud)
threshold = np.percentile(recon_error, 95)
X_scaled_df['Predicted_Fraud'] = (X_scaled_df['Reconstruction_Error'] > threshold).astype(int)

# Preview predictions
X_scaled_df[['Predicted_Fraud', 'Reconstruction_Error']].head(10)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#    Predicted_Fraud  Reconstruction_Error
# 0                0              0.000050
# 1                0              0.000059
# 2                0              0.000065
# 3                0              0.000051
# 4                0              0.000839
# 5                0              0.000074
# 6                0              0.000050
# 7                0              0.000168
# 8                0              0.000036
# 9                0              0.000078

# %% [markdown]
# ### 06-Step: Anomaly Detection

# %%
# ------------------- Step 6: Anomaly Detection ----------------------

# Reconstruct all NGO data
reconstructions = autoencoder.predict(X_scaled)

# Calculate reconstruction error (MSE)
mse = np.mean(np.power(X_scaled - reconstructions, 2), axis=1)

# Dynamic threshold (3 standard deviations above mean)
threshold = np.mean(mse) + 3 * np.std(mse)

# Label as Fraud (1) or Normal (0)
df1['Reconstruction_Error'] = mse
df1['Predicted_Fraud'] = (df1['Reconstruction_Error'] > threshold).astype(int)

# Summary
print("🔍 Threshold:", round(threshold, 6))
print("🚨 Potential Frauds Detected:", df1['Predicted_Fraud'].sum())

# Compare with actual labels if available
if 'Is_Fraud' in df1.columns:
    from sklearn.metrics import confusion_matrix, classification_report

    print("\n📊 Confusion Matrix:")
    print(confusion_matrix(df1['Is_Fraud'], df1['Predicted_Fraud']))

    print("\n📈 Classification Report:")
    print(classification_report(df1['Is_Fraud'], df1['Predicted_Fraud']))
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 🔍 Threshold: 0.021503
# 🚨 Potential Frauds Detected: 7
#
# 📊 Confusion Matrix:
# [[965   5]
#  [ 27   2]]
#
# 📈 Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       970
#            1       0.29      0.07      0.11        29
#
#     accuracy                           0.97       999
#    macro avg       0.63      0.53      0.55       999
# weighted avg       0.95      0.97      0.96       999

# %% [markdown]
# ### 07-Step: Visualizations

# %%
# ------------------- Step 7: Visualizations ----------------------

import matplotlib.pyplot as plt

# Count of fraud vs non-fraud
fraud_counts = df1['Predicted_Fraud'].value_counts()

# Labels
labels = ['Legit NGOs (0)', 'Fraudulent NGOs (1)']
colors = ['#4CAF50', '#F44336']  # Green for legit, Red for fraud

# Plot pie chart
plt.figure(figsize=(7, 7))
plt.pie(
    fraud_counts,
    labels=labels,
    autopct='%1.1f%%',
    startangle=140,
    colors=colors,
    explode=(0.05, 0.1),
    shadow=True,
    textprops={'fontsize': 12}
)

plt.title("NGO Fraud Detection Results (Autoencoder Model)", fontsize=14, fontweight='bold')
plt.show()

# %%
# Show few detected fraud NGOs
print("🚨 Top Detected Fraudulent NGOs:")
df1[df1['Predicted_Fraud'] == 1]
# Out:
# 🚨 Top Detected Fraudulent NGOs:
#           Date       Applicant_Name                       NGO_Name  \
# 154 2023-07-25            Hira Shah        Green Villages Pakistan
# 239 2023-09-08          Zara Saleem         Green Pakistan Welfare
# 698 2022-09-18    Zara Yaseen Ahmed         Green Pakistan Welfare
# 833 2022-01-24          Usman Sabir        Green Villages Pakistan
# 844 2021-08-21   Sayed Tanveer Khan      Sehat & Taleem Initiative
# 863 2024-09-25           Qasim Raza      Sehat & Taleem Initiative
# 969 2024-08-16  Muhammad Asghar Bux  Sahara Development Foundation
#
#     City_Town_Village                              Project_Name  \
# 154            Multan  Covid-19 Awareness & Vaccination Support
# 239            Chagai               Rural School Rehabilitation
# 698            Chagai               Rural School Rehabilitation
# 833        Faisalabad                     Girls EDUCATION Drive
# 844            Ormara        Maternal and Child Health Outreach
# 863            Ormara        Maternal and Child Health Outreach
# 969          Peshawar            Disaster Relief Rapid Response
#
#      Requested_Amount_PKR  Legitimate_Estimate_PKR  \
# 154             5888700.0                3698727.0
# 239             5461500.0                5461500.0
# 698             5461111.0                5461100.0
# 833            69528000.0               10948793.0
# 844            77107100.0               77107100.0
# 863            55687369.0               55687321.0
# 969            99950922.0               96950865.0
#
#                       Fraud_Type                       Fraud_Indicator  \
# 154  Expense/Reimbursement Fraud       Beneficiary counts inconsistent
# 239                     Approved             Compliant with Guidelines
# 698                     Approved             Compliant with Guidelines
# 833   Procurement & Vendor Fraud  Invoices lack vendor contact details
# 844                     Approved             Compliant with Guidelines
# 863                     Approved             Compliant with Guidelines
# 969                     Approved             Compliant with Guidelines
#
#      Population_Census_Record     Invoice_ID                      Vendor_Name  \
# 154                 2215381.0   INV-AFVNUY82           Metro Office Solutions
# 239                   23652.0   INV-KK1R6L5A           Bright Future Printers
# 698                   23652.0   INV-KK1R6L7R           Bright Future Printers
# 833                 3691999.0   INV-KL5EZ2SD  United Medical & Relief Vendors
# 844                   65222.0  INV-IZ1BN5HGF           Bright Future Printers
# 863                   65222.0  INV-IZ1BN33GY           Bright Future Printers
# 969                 1905975.0  INV-U9PIYIYUV           Metro Office Solutions
#
#       Bank_Reference_No                    Bank_Name  Is_Fraud  Fund_Gap_PKR  \
# 154   BR-MCB-8984615492             MCB Bank Limited         1     2189973.0
# 239   BR-HBL-4066884000           Habib Bank Limited         0           0.0
# 698   BR-HBL-4066884505           Habib Bank Limited         0          11.0
# 833  BR-MEBL-3910202584                  Meezan Bank         1    58579207.0
# 844   BR-SCB-4289062045  Standard Chartered Pakistan         0           0.0
# 863   BR-SCB-4289062202  Standard Chartered Pakistan         0          48.0
# 969    BR-UBL-339322538          United Bank Limited         0     3000057.0
#
#      Funding_per_Capita  Bank_Frequency  Reconstruction_Error  Predicted_Fraud
# 154            2.658098              69              0.031103                1
# 239          230.910705             132              0.024349                1
# 698          230.894258             132              0.024346                1
# 833           18.832074              96              0.037678                1
# 844         1182.225323             103              0.048010                1
# 863          853.812655             103              0.021592                1
# 969           52.440836              99              0.188779                1

# %% [markdown]
# ### Final Insight Note
#
# This notebook presents an exploratory data analysis and an anomaly detection approach using an autoencoder model to identify potential fraudulent activities in the provided Pakistan NGO dataset.
#
# The initial data exploration revealed the distribution of projects across different NGOs, project types, and cities, providing a foundational understanding of the dataset's structure and content. Visualizations highlighted the frequency of different fraud types and the spatial distribution of projects.
#
# Feature engineering involved cleaning numerical data, calculating the "Fund Gap" between requested and legitimate amounts, determining "Funding per Capita" based on population records, and analyzing "Bank Frequency". These engineered features were then used as input for the autoencoder model.
#
# The autoencoder was trained on the 'normal' (non-fraudulent) data to learn the typical patterns of legitimate transactions. By calculating the reconstruction error for all data points, the model identified instances that deviate significantly from the learned normal patterns, flagging them as potential anomalies or frauds.
#
# The anomaly detection results show a threshold for identifying potential fraud based on reconstruction error. The confusion matrix and classification report provide metrics on the model's performance in distinguishing between legitimate and fraudulent cases based on the available 'Is_Fraud' labels. While the model shows high precision for detecting fraud, the recall is relatively low, indicating that it identifies a subset of the actual fraudulent cases.
#
# The final visualization provides a pie chart showing the proportion of potentially fraudulent NGOs detected by the model compared to legitimate ones based on the defined threshold. A list of the top detected fraudulent NGOs is also presented.
#
# **Key Takeaways:**
#
# *   The autoencoder model can be a valuable tool for anomaly detection in NGO financial data, identifying transactions or projects that deviate from expected patterns.
# *   Engineered features such as Fund Gap and Funding per Capita can help highlight suspicious activities.
# *   The current model identified a number of potential fraud cases, but further refinement and potentially more sophisticated models or additional data features could improve the recall and overall performance of the fraud detection system.
# *   The identified potentially fraudulent NGOs warrant further investigation and auditing.
#
# This analysis serves as a starting point for building a robust fraud detection system for NGOs in Pakistan, contributing to increased transparency and accountability in the non-profit sector.
